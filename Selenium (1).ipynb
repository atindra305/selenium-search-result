# %%
# !pip install selenium

# %%
from selenium import webdriver
driver = webdriver.Chrome(executable_path="C:/Users/sadhi/Desktop/Practice/Selenium/chromedriver_win32/chromedriver")
# Out:
# <ipython-input-2-b04d2c2e12e7>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:/Users/sadhi/Desktop/Practice/Selenium/chromedriver_win32/chromedriver")

# %%
driver.get('https://economictimes.indiatimes.com/markets/stocks/news/gautam-adani-pips-warren-buffett-to-become-worlds-5th-richest-as-stocks-rally-up-to-235/articleshow/91070214.cms')

# %%
input_tag = driver.find_element_by_xpath('/html/body/main/div[10]/div/div[1]/div[3]/div/article/div[2]')
# Out:
# <ipython-input-4-64381600d842>:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   input_tag = driver.find_element_by_xpath('/html/body/main/div[10]/div/div[1]/div[3]/div/article/div[2]')

# %%
# input_tag.send_keys('Full stack')

# %%
# input_tag.submit()

# %%
# driver.back()

# %%
# driver.forward()

# %%
# driver.refresh()

# %%
# driver.maximize_window()

# %%
# driver.minimize_window()

# %%
# driver.set_window_size(500,700)

# %%
# !python -m pip install bs4 --user

# %%
from bs4 import BeautifulSoup

# %%
data = BeautifulSoup(driver.page_source)

# %%
driver.page_source
# Out:
# '<html class="no-js free_user win chrome chrome1 webkit webkit5 typefree" lang="en" data-adaptive="0"><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><title>Gautam Adani Net Worth: Gautam Adani pips Warren Buffett to become world\'s 5th richest as stocks rally up to 235% - The Economic Times</title><meta content="According to Forbes Real-Time Billionaires List, Adani\'s wealth stood at $123.7 billion as of Friday\'s close, racing past Buffett\'s $121.7 billion." name="description"><meta name="news_keywords" content="Gautam Adani Net Worth,Warren Buffett wealth,Warren Bufft net worth,Gautam Adani wealth,Gautam Adani,Warren Buffett,adani shares,elon musk,india\'s richest person,Warren Buffet Net Worth"><meta content="Gautam Adani Net Worth,Warren Buffett wealth,Warren Bufft net worth,Gautam Adani wealth,Gautam Adani,Warren Buffett,adani shares,elon musk,india\'s richest person,Warren Buffet Net Worth" name="keywords"><meta property="article:tag" content="Gautam
# ...

# %%
headings = data.findAll('div', attrs={'class':'artText medium'})
for i in headings:
    print(i.text)
# Out:
# New Delhi: Billionaire Industrialist Gautam Adani has edged past veteran investor Warren Buffett to become the world's fifth-richest person, according to data by Forbes. The sharp run-up in Adani Group stocks has led him to this feat.
#
# According to Forbes’ Real-Time Billionaires List, Adani's wealth stood at $123.7 billion as of Friday's close, racing past Buffett's $121.7 billion.
#
# Gautam Adani is the founder and Chairman of Adani Groups, which is engaged in multiple businesses, including ports, edible oil, airports, power generation and distribution.
#
# The group has seven listed companies, including Adani Enterprises, Adani Ports, Adani Power, Adani Total Gas, Adani Green Energy and Adani Transmission. Adani Wilmar is their latest debutant, which was listed earlier this year.
#
# Out of them, three companies have delivered multibagger returns in the year so far. Adani Wilmar is up by 235 per cent compared to its issue price, whereas Adani Power has zoomed 170 per cent.
#
# ...
