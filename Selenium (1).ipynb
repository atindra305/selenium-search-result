# %%
# !pip install selenium
# Out:
# ...
#      |████████████████████████████████| 963 kB 142 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 359 kB 127 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 58 kB 157 kB/s eta 0:00:01
# ...

# %%
from selenium import webdriver
driver = webdriver.Chrome(executable_path="/Users/jazz/Downloads/chromedriver")
# Out:
# <ipython-input-3-a789d43b0e79>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="/Users/jazz/Downloads/chromedriver")

# %%
driver.get('https://google.com')

# %%
input_tag = driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
# Out:
# <ipython-input-5-963b4affd2b5>:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   input_tag = driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')

# %%
input_tag.send_keys('Full stack')

# %%
input_tag.submit()

# %%
driver.back()

# %%
driver.forward()

# %%
driver.refresh()

# %%
driver.maximize_window()

# %%
driver.minimize_window()

# %%
driver.set_window_size(500,700)

# %%
# !python -m pip install bs4 --user
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=7078f4027c8675b3f5140b13bc2c8e46dcf3e8b9233d06c3d09be45b74501c2e
#   Stored in directory: /Users/jazz/Library/Caches/pip/wheels/75/78/21/68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# ...

# %%
from bs4 import BeautifulSoup

# %%
data = BeautifulSoup(driver.page_source)

# %%
driver.page_source
# Out:
# '<html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en-IN"><head><meta charset="UTF-8"><meta content="origin" name="referrer"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Full stack - Google Search</title><script src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.fQLVS3SAB_U.O/m=gapi_iframes,googleapis_client/rt=j/sv=1/d=1/ed=1/rs=AHpOoo9-gtqpJORJvBFDdao_eAhWe8xjHw/cb=gapi.loaded_0" nonce="" async=""></script><script nonce="">(function(){\nvar b=window.addEventListener;window.addEventListener=function(a,c,d){"unload"!==a&&b(a,c,d)};}).call(this);(function(){window.google={kEI:\'xOImYpadMJ2D4t4P0PyQcA\',kEXPI:\'31\',kBL:\'pI3-\'};google.sn=\'web\';google.kHL=\'en-IN\';})();(function(){\nvar f=this||self;var h,k=[];function l(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||h}function m(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=
# ...

# %%
headings = data.findAll('h3', attrs={'class':'LC20lb MBeuO DKV0Md'})
for i in headings:
    print(i.text)
# Out:
# What is Full Stack - W3Schools
# What Is a Full Stack Developer & What Do They Do?
# Learn The Difference Between Full Stack & Mean Stack Developer
# What is a full-stack Python developer? - YourStory
# What is a Full Stack Developer? Back End + Front End = Full ...
# What is full stack development ? - GeeksforGeeks
# What is a Full Stack Developer? Find out here! - Skillcrush
# Become a Full Stack Web Developer - Udacity
# What Does A Full Stack Developer Do? | Le Wagon
# What is a Full Stack Developer? Back End + Front End = Full ...
# Who Is a Full Stack Developer? - Simplilearn
# What is a Full-Stack Web Developer Exactly? A Complete Guide
